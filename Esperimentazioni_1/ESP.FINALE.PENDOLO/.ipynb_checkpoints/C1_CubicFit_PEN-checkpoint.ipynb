# %% [markdown]
# ### Given two list of x and y coordinates, and a list of errors on y, find the parabola that minimizes the sum of square distances between the parabola and the (x,y) points.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import *

# %%
xx, yy, aa, bb, cc, dd = symbols('xx yy aa bb cc dd')

# %% [raw]
# Si comprimono i valori di x tra -1 e 1 : se non serve decommentare l'ultima riga

# %%
xdataor = np.array([18.2,28.2,38.2,48.2,58.2,68.2,78.2,88.2,98.2])/(10**2)
npoint = len(xdataor)
npoint
ax,bx = float(xdataor[0]),float(xdataor[npoint-1])
apx,bpx = 2./(bx-ax),(bx + ax)/(bx - ax)
print(ax)
print(bx)
print(apx)
print(bpx)
xdata = xdataor*apx - bpx
xdata
xdata=xdataor
# Out:
# 0.182
# 0.982
# 2.5
# 1.4549999999999998

# %%
ydata = np.array([2.137,2.005,1.931,1.897,1.893,1.910,1.942,1.984,2.035])
yerr = np.array([0.001]*9)
if (len(xdata)!=len(ydata)): print ("dimensioni vettori disuguali")
if (len(yerr)!=len(ydata)): print ("dimensioni vettori disuguali")
#ydata

# %% [markdown]
# We want to find the parameters $a$,$b$,$c$ and $d$ of the cubic $y = d x^3 +c x^2 + b x + a$ which minimize:
# $ \chi^2 = \sum_i \frac{(y_i - d x^3-c x_i^2 - b x_i - a)^2}{\sigma_i^2}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calcolo matrice H e matrice trasposta

# %%
vect1=np.array([1]*9)
vect2=xdata
vect3=xdata**2
vect4=xdata**3
matH=np.matrix([vect1,vect2,vect3,vect4])
matHT = matH.T
#matH,matHT

# %% [markdown]
# calcolo matrice della varianza

# %%
varyinv = 1./(yerr*yerr)
matC=np.diag(varyinv)
#varyinv,matC

# %% [raw]
# Calcolo vettore Y

# %%
ydataprovv=ydata
matY=ydataprovv.reshape((-1, 1))
#matY

# %% [markdown]
# calcolo matrice A dei parametri

# %%
mat1=matH*matC*matHT
mat1_inv=np.linalg.inv(mat1)
mat2=matH*matC*matY
matA=np.dot(mat1_inv,mat2)
#matA

# %% [raw]
# Calcolo parametri fit (Attenzione a cifre significative e unita' di misura!!)

# %%
a, b, c, d = matA[0],matA[1],matA[2],matA[3]
print (" a = ", a)
print (" b = ", b)
print (" c = ", c)
print (" d = ", d)
# Out:
#  a =  [[2.50842839]]
#  b =  [[-2.64560546]]
#  c =  [[3.47432684]]
#  d =  [[-1.29713805]]

# %% [raw]
# Calcolo varianze ed errori sui parametri (Attenzione a cifre significative e unita' di misura!!)

# %%
vara, varb, varc, vard = mat1_inv[0,0], mat1_inv[1,1], mat1_inv[2,2],mat1_inv[3,3]
erra=np.sqrt(vara)
errb=np.sqrt(varb)
errc=np.sqrt(varc)
errd=np.sqrt(vard)
print (" errore su a = ",erra)
print (" errore su b = ",errb)
print (" errore su c = ",errc)
print (" errore su d = ",errd)
# Out:
#  errore su a =  0.0038281125103655496
#  errore su b =  0.02472919080549733
#  errore su c =  0.04659266705583762
#  errore su d =  0.026485071923485648

# %% [markdown]
# Plot, adding extra points for the cubic.

# %%
thickxdata = np.arange(0.1,1.05,0.01)
thx2=thickxdata**2
thx3=thickxdata**3
thydata=d*thx3+c*thx2+b*thickxdata+a
thiyarr=np.array(thydata)
thickydata=thiyarr.T

# %%
fig, ax = plt.subplots()
ax.set_xlabel('Distanza (m)')
ax.set_ylabel('Periodo (s)')
ax.set_xlim(0.1, 1.05); ax.set_ylim(1.850, 2.200) 
ax.grid()
plt.plot(thickxdata,thickydata, color="royalblue",label='P(x) - 2° grado')
plt.errorbar(xdata,ydata,yerr=yerr,fmt='o', label='x - massa mobile', color="crimson")
ax.legend()
plt.savefig("C1_Cubic.png")

# %% [raw]
# Calcolo X^2 e errore standard della stima

# %%
x2=xdata**2
x3=xdata**3
thyatt=d*x3+c*x2+b*xdata+a
ydatatt=np.array(thyatt)
scarto1 = (ydata-ydatatt)/yerr
scarto2 = (ydata-ydatatt)
chi2 = (scarto1*scarto1).sum()
errstSq = (scarto2*scarto2/(npoint-4)).sum()
errst = np.sqrt(errstSq)
print (" Chi^2 = ",chi2)
print (" errore standard della stima = ",errst)
# Out:
#  Chi^2 =  70.49422799422615
#  errore standard della stima =  0.0037548429526206863

# %% [raw]
# Calcolo coefficiente di determinazione

# %%
sum_y = (ydata).sum()
ymean=sum_y/npoint
ameany = ydata-ymean
vary = (ameany*ameany).sum()
scarto3=ydatatt-ymean
var_numeratore=(scarto3*scarto3).sum()
detercoeff2=var_numeratore/vary
detercoeff=np.sqrt(detercoeff2)
print ("coefficiente determinazione = ",detercoeff)
# Out:
# coefficiente determinazione =  0.9993044969824101
